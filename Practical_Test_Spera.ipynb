# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
df = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4265  2632-UCGVD    Male              1     Yes         No      66
# 6371  1535-VTJOQ  Female              0      No         No      24
# 5711  1891-UAWWU  Female              1     Yes         No      20
# 2396  4083-BFNYK  Female              1     Yes         No      38
# 3682  3716-BDVDB    Male              0      No         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4265          Yes           Yes     Fiber optic                   No  ...
# 6371          Yes           Yes              No  No internet service  ...
# 5711          Yes           Yes     Fiber optic                   No  ...
# 2396          Yes           Yes     Fiber optic                  Yes  ...
# 3682          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (7032, 20)

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 20)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges)
# Out:
# <ipython-input-17-e4980e5e83ff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.TotalCharges = pd.to_numeric(df.TotalCharges)

# %%
df.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df[df.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# ...

# %%
# Display the first few rows of the specified columns
columns_to_view = ['MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
print(df[columns_to_view].head())

# Display the unique values in each column to identify inconsistencies
for column in columns_to_view:
    print(f"Unique values in {column}: {df[column].unique()}")
# Out:
#       MultipleLines OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0  No phone service             No          Yes               No          No
# 1                No            Yes           No              Yes          No
# 2                No            Yes          Yes               No          No
# 3  No phone service            Yes           No              Yes         Yes
# 4                No             No           No               No          No
#
#   StreamingTV StreamingMovies
# 0          No              No
# 1          No              No
# 2          No              No
# 3          No              No
# 4          No              No
# Unique values in MultipleLines: ['No phone service' 'No' 'Yes']
# Unique values in OnlineSecurity: ['No' 'Yes' 'No internet service']
# Unique values in OnlineBackup: ['Yes' 'No' 'No internet service']
# Unique values in DeviceProtection: ['No' 'Yes' 'No internet service']
# ...

# %%
def print_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
print_values(df)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_and_no = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_and_no:
    df[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# <ipython-input-24-19f9d589576b>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].replace({'Yes': 1,'No': 0},inplace=True)
# <ipython-input-24-19f9d589576b>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
df['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# <ipython-input-25-7f2ac4c24de4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace({'Female':1,'Male':0},inplace=True)
# <ipython-input-25-7f2ac4c24de4>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df.gender.unique()
# Out:
# array([1, 0])

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df = pd.get_dummies(data=df, columns=['InternetService','Contract','PaymentMethod'])
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4177       0              0        0           1      21             1
# 1527       0              0        1           1      72             1
# 3967       1              0        1           0      32             1
# 2268       1              0        0           0      40             1
# 2753       1              0        0           0       1             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4177              0               0             0                 0  ...
# 1527              0               0             0                 0  ...
# 3967              0               0             0                 0  ...
# 2268              0               0             0                 0  ...
# 2753              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
df = df.replace({True: 1, False: 0})
# Out:
# <ipython-input-30-0ea0dd73b5d1>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({True: 1, False: 0})

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4553       0              0        1           0      72             1
# 3865       1              0        0           1       1             1
# 3809       0              0        0           0      50             1
# 2440       0              0        1           1      32             1
# 4282       1              0        1           1      52             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4553              1               1             1                 1  ...
# 3865              1               0             0                 0  ...
# 3809              0               0             0                 0  ...
# 2440              0               0             0                 0  ...
# 4282              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# ...

# %%
df.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          int64
# ...

# %%
scale_step = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[scale_step] = scaler.fit_transform(df[scale_step])

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %%
# Save the modified dataset to a new CSV file
output_file = '/content/modified_telco_customer_churn.csv'
df.to_csv(output_file, index=False)

# Provide a download link (for Google Colab or similar environments)
from google.colab import files
files.download(output_file)

# %%
from matplotlib import pyplot as plt

# Extracting tenure data for customers who churned and did not churn
tenure_churn_no = df[df.Churn == 0].tenure  # Adjusted for binary representation of Churn
tenure_churn_yes = df[df.Churn == 1].tenure

# Plotting the histogram
plt.figure(figsize=(10, 6))  # Set figure size for better readability
plt.hist(
    [tenure_churn_yes, tenure_churn_no],
    bins=20,  # You can adjust the number of bins for better resolution
    rwidth=0.95,
    color=['green', 'red'],
    label=['Churn = Yes', 'Churn = No']
)

# Adding labels, title, and legend
plt.xlabel("Tenure (Scaled)", fontsize=12)
plt.ylabel("Number of Customers", fontsize=12)
plt.title("Customer Churn vs Tenure", fontsize=14)
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Optional: Add a grid for better visualization
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count plot for Churn
plt.figure(figsize=(8, 6))
sns.countplot(x='Churn', data=df)
plt.title('Distribution of Churn vs. Non-Churn Customers')
plt.show()

# %%
# Select only the numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
plt.figure(figsize=(12, 10))
correlation_matrix = numeric_cols.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Box plot for features against Churn
key_features = ['tenure', 'MonthlyCharges', 'TotalCharges']

for feature in key_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Churn', y=feature, data=df)
    plt.title(f'{feature} vs. Churn')
    plt.show()

# %%
categorical_cols = [
    'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
    'InternetService_DSL', 'InternetService_Fiber optic', 'InternetService_No',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
    'PaperlessBilling', 'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)',
    'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'
]

# %%
from scipy.stats import chi2_contingency

for col in categorical_cols:
    contingency_table = pd.crosstab(df[col], df['Churn'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f'Chi-Square Test for {col}:')
    print(f'Chi2: {chi2}, p-value: {p}\n')
# Out:
# Chi-Square Test for gender:
# Chi2: 0.4754545372738629, p-value: 0.490488470706551
#
# Chi-Square Test for SeniorCitizen:
# Chi2: 158.4408162893713, p-value: 2.4792557203954705e-36
#
# Chi-Square Test for Partner:
# Chi2: 157.50315146557506, p-value: 3.97379757451591e-36
#
# Chi-Square Test for Dependents:
# Chi2: 186.32163933855873, p-value: 2.0196592017051303e-42
#
# Chi-Square Test for PhoneService:
# Chi2: 0.8737327674431736, p-value: 0.34992398942431924
#
# Chi-Square Test for MultipleLines:
# Chi2: 11.08687591455858, p-value: 0.0008694082815826175
#
# Chi-Square Test for InternetService_DSL:
# Chi2: 107.77987377720264, p-value: 3.0035094040065033e-25
#
# Chi-Square Test for InternetService_Fiber optic:
# Chi2: 663.3564569173802, p-value: 2.782210278669653e-146
#
# Chi-Square Test for InternetService_No:
# Chi2: 362.94784884289265, p-value: 6.4225207979072035e-81
#
# Chi-Square Test for OnlineSecurity:
# Chi2: 205.41578737378245, p-value: 1.37424000884718e-46
#
# ...

# %%
from scipy.stats import ttest_ind

for col in numeric_cols:
    churned = df[df['Churn'] == 'Yes'][col]
    non_churned = df[df['Churn'] == 'No'][col]
    t_stat, p_value = ttest_ind(churned, non_churned)
    print(f'T-Test for {col}:')
    print(f't-statistic: {t_stat}, p-value: {p_value}\n')
# Out:
# T-Test for gender:
# t-statistic: nan, p-value: nan
#
# T-Test for SeniorCitizen:
# t-statistic: nan, p-value: nan
#
# T-Test for Partner:
# t-statistic: nan, p-value: nan
#
# T-Test for Dependents:
# t-statistic: nan, p-value: nan
#
# T-Test for tenure:
# t-statistic: nan, p-value: nan
#
# T-Test for PhoneService:
# t-statistic: nan, p-value: nan
#
# T-Test for MultipleLines:
# t-statistic: nan, p-value: nan
#
# T-Test for OnlineSecurity:
# t-statistic: nan, p-value: nan
#
# T-Test for OnlineBackup:
# t-statistic: nan, p-value: nan
#
# T-Test for DeviceProtection:
# t-statistic: nan, p-value: nan
#
# T-Test for TechSupport:
# t-statistic: nan, p-value: nan
#
# T-Test for StreamingTV:
# t-statistic: nan, p-value: nan
#
# T-Test for StreamingMovies:
# t-statistic: nan, p-value: nan
#
# T-Test for PaperlessBilling:
# t-statistic: nan, p-value: nan
#
# T-Test for MonthlyCharges:
# t-statistic: nan, p-value: nan
#
# T-Test for TotalCharges:
# t-statistic: nan, p-value: nan
#
# ...

# %% [markdown]
# # ***Feature Engineering***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/modified_telco_customer_churn.csv')

# Now check if the DataFrame is loaded correctly
print(df.head())
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       1              0        1           0  0.000000             0
# 1       0              0        0           0  0.464789             1
# 2       0              0        0           0  0.014085             1
# 3       0              0        0           0  0.619718             0
# 4       1              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Assuming 'Churn' is your target variable and you've already encoded categorical variables
X = df.drop('Churn', axis=1)
y = df['Churn']

model = RandomForestClassifier()
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_
feature_names = X.columns
indices = np.argsort(importances)[::-1]

# Print feature ranking
print("Feature ranking:")
for f in range(X.shape[1]):
    print(f"{f + 1}. feature {feature_names[indices[f]]} ({importances[indices[f]]})")

# Plot feature importances
plt.figure(figsize=(16, 8))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature TotalCharges (0.18389025600193193)
# 2. feature MonthlyCharges (0.17428844074013736)
# 3. feature tenure (0.16459417531385248)
# 4. feature Contract_Month-to-month (0.06221054353287782)
# 5. feature InternetService_Fiber optic (0.040026593706415016)
# 6. feature PaymentMethod_Electronic check (0.028688560937139583)
# 7. feature gender (0.027807981981465363)
# 8. feature PaperlessBilling (0.025031873380712014)
# 9. feature Partner (0.023013808384734838)
# 10. feature OnlineSecurity (0.02174118480060009)
# 11. feature Contract_Two year (0.021415362569817752)
# 12. feature OnlineBackup (0.020974776684534423)
# 13. feature SeniorCitizen (0.020826034495273253)
# 14. feature TechSupport (0.020796392918173943)
# 15. feature MultipleLines (0.01919049320960263)
# 16. feature Dependents (0.019053296607841084)
# 17. feature DeviceProtection (0.018750213089888463)
# 18. feature StreamingMovies (0.016968858398907292)
# 19. feature StreamingTV (0.015923418232646765)
# ...

# %%
# Assuming df is your DataFrame
df['TenurePerMonth'] = df['tenure'] / df['MonthlyCharges']
df['AvgMonthlyCharge'] = df['TotalCharges'] / (df['tenure'] + 1)  # To avoid division by zero

# Document the new features
print(df[['TenurePerMonth', 'AvgMonthlyCharge']].head())
# Out:
#    TenurePerMonth  AvgMonthlyCharge
# 0        0.000000          0.001275
# 1        1.207009          0.147370
# 2        0.039761          0.010167
# 3        2.589675          0.129801
# 4        0.026987          0.015117

# %%
from sklearn.decomposition import PCA

# Applying PCA
pca = PCA(n_components=10)  # Adjust the number of components
X_pca = pca.fit_transform(X)

# Print explained variance ratio
print(pca.explained_variance_ratio_)
# Out:
# [0.19433434 0.14738591 0.08616215 0.05451667 0.05010908 0.04669494
#  0.04356388 0.04177707 0.03985645 0.03887046]

# %% [markdown]
# # ***Model Development***

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/modified_telco_customer_churn.csv')

# Check the first few rows of the DataFrame to ensure it's loaded correctly
print(df.head())
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       1              0        1           0  0.000000             0
# 1       0              0        0           0  0.464789             1
# 2       0              0        0           0  0.014085             1
# 3       0              0        0           0  0.619718             0
# 4       1              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
from sklearn.model_selection import train_test_split

# Assuming the DataFrame is already encoded and ready to use
X = df.drop('Churn', axis=1)
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
import xgboost as xgb

xgboost = xgb.XGBClassifier()
xgboost.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.svm import SVC

svm = SVC(probability=True)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
from sklearn.model_selection import cross_val_score

cv_log_reg = cross_val_score(log_reg, X_train, y_train, cv=5)
cv_random_forest = cross_val_score(random_forest, X_train, y_train, cv=5)
cv_xgboost = cross_val_score(xgboost, X_train, y_train, cv=5)
cv_svm = cross_val_score(svm, X_train, y_train, cv=5)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# Adjusted parameter grid
param_grid = {'C': [0.1, 1, 10, 100], 'penalty': ['l2'], 'solver': ['lbfgs']}

grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
# Out:
# {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# Adjusted parameter distribution
param_dist = {'n_estimators': [50, 100, 200], 'max_features': [None, 'sqrt', 'log2'],
              'max_depth': [4, 6, 8], 'criterion': ['gini', 'entropy']}

random_search = RandomizedSearchCV(RandomForestClassifier(), param_dist, n_iter=10, cv=5, random_state=42)
random_search.fit(X_train, y_train)
print(random_search.best_params_)
# Out:
# {'n_estimators': 200, 'max_features': 'log2', 'max_depth': 6, 'criterion': 'gini'}

# %%
# !pip install optuna

# %%
from sklearn.model_selection import train_test_split

# Data split (assuming df is your DataFrame)
X = df.drop('Churn', axis=1)
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score

# Define objective function for Optuna
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 2, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion,
        random_state=42
    )

    score = cross_val_score(model, X_train, y_train, cv=5, scoring=make_scorer(f1_score, average='binary'))
    return score.mean()

# %%
# Create and run the Optuna study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-12-05 05:46:47,075] A new study created in memory with name: no-name-605b75f7-2d0e-4c72-a2bd-33c85ac67ee2
# [I 2024-12-05 05:46:59,750] Trial 0 finished with value: 0.583806116714259 and parameters: {'n_estimators': 289, 'max_depth': 8, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 0 with value: 0.583806116714259.
# [I 2024-12-05 05:47:03,771] Trial 1 finished with value: 0.449663207625748 and parameters: {'n_estimators': 197, 'max_depth': 3, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 0 with value: 0.583806116714259.
# [I 2024-12-05 05:47:07,916] Trial 2 finished with value: 0.44937980353843987 and parameters: {'n_estimators': 180, 'max_depth': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 0 with value: 0.583806116714259.
# ...

# %%
# Print best hyperparameters
print("Best hyperparameters:", study.best_params)
# Out:
# Best hyperparameters: {'n_estimators': 277, 'max_depth': 10, 'max_features': 'sqrt', 'criterion': 'entropy'}

# %%
# Train final model with best hyperparameters
best_params = study.best_params
final_model = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion'],
    random_state=42
)
final_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=277,
#                        random_state=42)

# %% [markdown]
# # ***Model Evaluation***

# %%
from sklearn.linear_model import LogisticRegression

# Refit the model with the best parameters
log_reg_best = LogisticRegression(C=100, penalty='l2', solver='lbfgs')
log_reg_best.fit(X_train, y_train)

# Make predictions
y_pred_log_reg_best = log_reg_best.predict(X_test)

# Evaluate the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

print("Best Logistic Regression Performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_log_reg_best)}")
print(f"Precision: {precision_score(y_test, y_pred_log_reg_best)}")
print(f"Recall: {recall_score(y_test, y_pred_log_reg_best)}")
print(f"F1 Score: {f1_score(y_test, y_pred_log_reg_best)}")
print(f"ROC AUC Score: {roc_auc_score(y_test, log_reg_best.predict_proba(X_test)[:, 1])}")
# Out:
# Best Logistic Regression Performance:
# Accuracy: 0.795734597156398
# Precision: 0.6377118644067796
# Recall: 0.5365418894830659
# F1 Score: 0.5827686350435625
# ROC AUC Score: 0.839317873989199

# %%
log_reg = LogisticRegression(C=100, penalty='l2', solver='lbfgs')
log_reg.fit(X_train, y_train)

# Generate predictions
y_pred_log_reg = log_reg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm_log_reg = confusion_matrix(y_test, y_pred_log_reg)
print("Confusion Matrix for Logistic Regression:")
print(cm_log_reg)
# Out:
# Confusion Matrix for Logistic Regression:
# [[1378  171]
#  [ 260  301]]

# %%
import shap

# Explain model predictions using SHAP values
explainer = shap.Explainer(log_reg, X_train)
shap_values = explainer(X_test)
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# # ***Model Deployment Preparation***

# %%
import joblib

joblib.dump(log_reg, 'logistic_regression_model.pkl')
# Out:
# ['logistic_regression_model.pkl']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Logistic Regression Evaluation
y_pred_log_reg = log_reg_best.predict(X_test)
log_reg_metrics = {
    'Accuracy': accuracy_score(y_test, y_pred_log_reg),
    'Precision': precision_score(y_test, y_pred_log_reg),
    'Recall': recall_score(y_test, y_pred_log_reg),
    'F1 Score': f1_score(y_test, y_pred_log_reg),
    'ROC AUC Score': roc_auc_score(y_test, log_reg_best.predict_proba(X_test)[:, 1])
}

# Random Forest Evaluation
y_pred_rf = random_forest.predict(X_test)
rf_metrics = {
    'Accuracy': accuracy_score(y_test, y_pred_rf),
    'Precision': precision_score(y_test, y_pred_rf),
    'Recall': recall_score(y_test, y_pred_rf),
    'F1 Score': f1_score(y_test, y_pred_rf),
    'ROC AUC Score': roc_auc_score(y_test, random_forest.predict_proba(X_test)[:, 1])
}

# XGBoost Evaluation
y_pred_xgb = xgboost.predict(X_test)
xgb_metrics = {
    'Accuracy': accuracy_score(y_test, y_pred_xgb),
    'Precision': precision_score(y_test, y_pred_xgb),
    'Recall': recall_score(y_test, y_pred_xgb),
    'F1 Score': f1_score(y_test, y_pred_xgb),
    'ROC AUC Score': roc_auc_score(y_test, xgboost.predict_proba(X_test)[:, 1])
}

# Support Vector Machine Evaluation
y_pred_svm = svm.predict(X_test)
svm_metrics = {
    'Accuracy': accuracy_score(y_test, y_pred_svm),
    'Precision': precision_score(y_test, y_pred_svm),
    'Recall': recall_score(y_test, y_pred_svm),
    'F1 Score': f1_score(y_test, y_pred_svm),
    'ROC AUC Score': roc_auc_score(y_test, svm.predict_proba(X_test)[:, 1])
}

# Display the metrics
models = ['Logistic Regression', 'Random Forest', 'XGBoost', 'SVM']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC Score']

# Creating a DataFrame to display the metrics
import pandas as pd

metrics_df = pd.DataFrame([log_reg_metrics, rf_metrics, xgb_metrics, svm_metrics], index=models)
print(metrics_df)
# Out:
#                      Accuracy  Precision    Recall  F1 Score  ROC AUC Score
# Logistic Regression  0.795735   0.637712  0.536542  0.582769       0.839318
# Random Forest        0.786256   0.624434  0.491979  0.550349       0.816381
# XGBoost              0.766825   0.568047  0.513369  0.539326       0.810260
# SVM                  0.793365   0.643021  0.500891  0.563126       0.809576
